# %%
import seaborn as sns
from lib import get_attention, get_mean_attention

# %%
path = 'train/sa_imagenet_ddp/attention.log'
test_iter = 4
layer = 3
block = 2
head = 4
height = 3
width = 2
kernel = 7

attention = get_attention(path, test_iter, layer, block, head, height, width, kernel)
ax = sns.heatmap(attention)

# %%
path = 'train/sa_imagenet_ddp/attention.log'
layer = 3
block = 2
head = 4
height = 3
width = 2
kernel = 7

mean_attention = get_mean_attention(path, layer, block, head, height, width, kernel)
ax = sns.heatmap(mean_attention)
