# %%
import seaborn as sns
from lib import get_attention

# %%
path = 'train/kernel_7_attention_logger_temper_1.0/train.log'
epoch = 100
layer = 4
block = 3
head = 2
height = 2
width = 2
kernel = 7

attention = get_attention(path, epoch, layer, block, head, height, width, kernel)
ax = sns.heatmap(attention)
